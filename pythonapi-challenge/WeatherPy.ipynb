# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | igarka
# Processing Record 2 of Set 1 | qamdo
# Processing Record 3 of Set 1 | port saint john's
# Processing Record 4 of Set 1 | creel
# Processing Record 5 of Set 1 | rikaze
# Processing Record 6 of Set 1 | anadyr
# Processing Record 7 of Set 1 | port mathurin
# Processing Record 8 of Set 1 | solleftea
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | derbent
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | alotau
# Processing Record 14 of Set 1 | talnakh
# Processing Record 15 of Set 1 | st. john's
# Processing Record 16 of Set 1 | kalmunai
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | isafjordur
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | kapuskasing
# Processing Record 21 of Set 1 | polyarnyy
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | marsa alam
# Processing Record 24 of Set 1 | tolanaro
# Processing Record 25 of Set 1 | port augusta
# Processing Record 26 of Set 1 | adamstown
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | ola
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | puerto natales
# Processing Record 31 of Set 1 | severo-yeniseyskiy
# Processing Record 32 of Set 1 | altai
# Processing Record 33 of Set 1 | garbahaarrey
# Processing Record 34 of Set 1 | udachny
# Processing Record 35 of Set 1 | edinburgh of the seven seas
# Processing Record 36 of Set 1 | flying fish cove
# Processing Record 37 of Set 1 | mazamet
# Processing Record 38 of Set 1 | tazovsky
# Processing Record 39 of Set 1 | east tamworth
# Processing Record 40 of Set 1 | west island
# Processing Record 41 of Set 1 | borzya
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 44 of Set 1 | meulaboh
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | inekar
# City not found. Skipping...
# Processing Record 47 of Set 1 | yulinshi
# Processing Record 48 of Set 1 | gizo
# Processing Record 49 of Set 1 | belle fourche
# Processing Record 50 of Set 1 | neman
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 2 | fisterra
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | mejit
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | klyuchi
# Processing Record 8 of Set 2 | barra de santo antonio
# Processing Record 9 of Set 2 | inhambane
# Processing Record 10 of Set 2 | faget
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | ta`u
# Processing Record 13 of Set 2 | hawaiian paradise park
# Processing Record 14 of Set 2 | arkhonskaya
# Processing Record 15 of Set 2 | paraiso
# Processing Record 16 of Set 2 | moranbah
# Processing Record 17 of Set 2 | remire-montjoly
# Processing Record 18 of Set 2 | nova sintra
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | vila franca do campo
# Processing Record 23 of Set 2 | guaiba
# Processing Record 24 of Set 2 | whitehorse
# Processing Record 25 of Set 2 | uturoa
# Processing Record 26 of Set 2 | mayfield
# Processing Record 27 of Set 2 | san bernardo del viento
# Processing Record 28 of Set 2 | pangody
# Processing Record 29 of Set 2 | fort wellington
# Processing Record 30 of Set 2 | amga
# Processing Record 31 of Set 2 | invercargill
# Processing Record 32 of Set 2 | baghdad
# Processing Record 33 of Set 2 | chonchi
# Processing Record 34 of Set 2 | bamboo flat
# Processing Record 35 of Set 2 | sao martinho
# Processing Record 36 of Set 2 | alesund
# Processing Record 37 of Set 2 | papatowai
# Processing Record 38 of Set 2 | weno
# Processing Record 39 of Set 2 | dudinka
# Processing Record 40 of Set 2 | piton saint-leu
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | stanley
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | iskateley
# Processing Record 45 of Set 2 | ziro
# Processing Record 46 of Set 2 | hobyo
# Processing Record 47 of Set 2 | badger
# Processing Record 48 of Set 2 | hoa binh
# Processing Record 49 of Set 2 | haiku-pauwela
# Processing Record 0 of Set 3 | yerofey pavlovich
# Processing Record 1 of Set 3 | kerikeri
# Processing Record 2 of Set 3 | villa gesell
# Processing Record 3 of Set 3 | kingston
# Processing Record 4 of Set 3 | byron bay
# Processing Record 5 of Set 3 | guymon
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | horta
# Processing Record 8 of Set 3 | kenora
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | sao jose da coroa grande
# Processing Record 11 of Set 3 | lihue
# Processing Record 12 of Set 3 | hassi messaoud
# Processing Record 13 of Set 3 | ceeldheer
# Processing Record 14 of Set 3 | aasiaat
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | akobo
# Processing Record 17 of Set 3 | hodmezovasarhely
# Processing Record 18 of Set 3 | margaret river
# Processing Record 19 of Set 3 | djibo
# Processing Record 20 of Set 3 | keflavik
# Processing Record 21 of Set 3 | sabha
# Processing Record 22 of Set 3 | essaouira
# Processing Record 23 of Set 3 | garissa
# Processing Record 24 of Set 3 | obolo-eke (1)
# Processing Record 25 of Set 3 | zeven
# Processing Record 26 of Set 3 | bilibino
# Processing Record 27 of Set 3 | zaltan
# Processing Record 28 of Set 3 | talcahuano
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | urganch
# Processing Record 32 of Set 3 | saipan
# Processing Record 33 of Set 3 | mont-dore
# Processing Record 34 of Set 3 | constantia
# Processing Record 35 of Set 3 | sibolga
# Processing Record 36 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 3 | mangrol
# Processing Record 38 of Set 3 | tura
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | zeya
# Processing Record 41 of Set 3 | al qusiyah
# Processing Record 42 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 3 | celestun
# Processing Record 44 of Set 3 | tank
# Processing Record 45 of Set 3 | srandakan
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | kwang binh
# Processing Record 49 of Set 3 | mili
# Processing Record 0 of Set 4 | ko pha ngan
# Processing Record 1 of Set 4 | xinyuan
# Processing Record 2 of Set 4 | east wenatchee bench
# Processing Record 3 of Set 4 | scituate
# Processing Record 4 of Set 4 | adrian
# Processing Record 5 of Set 4 | axim
# Processing Record 6 of Set 4 | barcelos
# Processing Record 7 of Set 4 | ixtapa
# Processing Record 8 of Set 4 | piacabucu
# Processing Record 9 of Set 4 | kailua-kona
# Processing Record 10 of Set 4 | kostomuksha
# Processing Record 11 of Set 4 | al hoceima
# Processing Record 12 of Set 4 | balkashino
# Processing Record 13 of Set 4 | katsuren-haebaru
# Processing Record 14 of Set 4 | olonkinbyen
# Processing Record 15 of Set 4 | volodymyrets'
# City not found. Skipping...
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | alofi
# Processing Record 18 of Set 4 | susuman
# Processing Record 19 of Set 4 | altay
# Processing Record 20 of Set 4 | irakleion
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | holualoa
# Processing Record 23 of Set 4 | hancheng
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | bahia de kino
# Processing Record 26 of Set 4 | kralendijk
# Processing Record 27 of Set 4 | todos santos
# Processing Record 28 of Set 4 | batang
# Processing Record 29 of Set 4 | lompoc
# Processing Record 30 of Set 4 | lazaro cardenas
# Processing Record 31 of Set 4 | kapoeta
# Processing Record 32 of Set 4 | laikit, laikit ii (dimembe)
# Processing Record 33 of Set 4 | banda aceh
# Processing Record 34 of Set 4 | mountain home
# Processing Record 35 of Set 4 | atafu village
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | chadron
# Processing Record 38 of Set 4 | kurumkan
# Processing Record 39 of Set 4 | cradock
# Processing Record 40 of Set 4 | happy valley-goose bay
# Processing Record 41 of Set 4 | tuy hoa
# Processing Record 42 of Set 4 | aykhal
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | letterkenny
# Processing Record 45 of Set 4 | kayangel
# Processing Record 46 of Set 4 | gaspar hernandez
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | crane
# Processing Record 49 of Set 4 | betioky
# Processing Record 0 of Set 5 | tucurui
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | al kharijah
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | colonia
# Processing Record 5 of Set 5 | yung shue wan
# Processing Record 6 of Set 5 | vostryakovo
# Processing Record 7 of Set 5 | minas de marcona
# Processing Record 8 of Set 5 | monrovia
# Processing Record 9 of Set 5 | kinston
# Processing Record 10 of Set 5 | punta arenas
# Processing Record 11 of Set 5 | wytheville
# Processing Record 12 of Set 5 | alice springs
# Processing Record 13 of Set 5 | salinas
# Processing Record 14 of Set 5 | porto novo
# Processing Record 15 of Set 5 | jamaame
# Processing Record 16 of Set 5 | antofagasta
# Processing Record 17 of Set 5 | brisas de zicatela
# Processing Record 18 of Set 5 | fale old settlement
# Processing Record 19 of Set 5 | vorgashor
# Processing Record 20 of Set 5 | puerto aysen
# Processing Record 21 of Set 5 | kerch
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | salekhard
# Processing Record 24 of Set 5 | argo
# Processing Record 25 of Set 5 | plettenberg bay
# Processing Record 26 of Set 5 | humaita
# Processing Record 27 of Set 5 | cuenca
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | utrik
# Processing Record 30 of Set 5 | saudarkrokur
# Processing Record 31 of Set 5 | sabinanigo
# Processing Record 32 of Set 5 | pak phanang
# Processing Record 33 of Set 5 | xanxere
# Processing Record 34 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 35 of Set 5 | acarau
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | okayama
# Processing Record 38 of Set 5 | zhetybay
# City not found. Skipping...
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | glens falls north
# Processing Record 41 of Set 5 | reggane
# Processing Record 42 of Set 5 | tofol
# Processing Record 43 of Set 5 | tadine
# Processing Record 44 of Set 5 | la passe
# Processing Record 45 of Set 5 | onguday
# Processing Record 46 of Set 5 | new norfolk
# Processing Record 47 of Set 5 | viedma
# Processing Record 48 of Set 5 | miramichi
# Processing Record 49 of Set 5 | ust-nera
# Processing Record 0 of Set 6 | ulaangom
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | stony plain
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | ephraim
# Processing Record 6 of Set 6 | bayganin
# Processing Record 7 of Set 6 | port shepstone
# Processing Record 8 of Set 6 | pierre
# Processing Record 9 of Set 6 | pavlovka
# Processing Record 10 of Set 6 | longmen
# Processing Record 11 of Set 6 | mombaca
# Processing Record 12 of Set 6 | mandan
# Processing Record 13 of Set 6 | roha
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | belmonte
# Processing Record 16 of Set 6 | amahai
# Processing Record 17 of Set 6 | calderitas
# Processing Record 18 of Set 6 | chinde
# Processing Record 19 of Set 6 | marbletown
# Processing Record 20 of Set 6 | kupang
# Processing Record 21 of Set 6 | rosarito
# Processing Record 22 of Set 6 | yakoruda
# Processing Record 23 of Set 6 | el granada
# Processing Record 24 of Set 6 | bolama
# Processing Record 25 of Set 6 | trenton
# Processing Record 26 of Set 6 | key west
# Processing Record 27 of Set 6 | qui nhon
# Processing Record 28 of Set 6 | xilin hot
# Processing Record 29 of Set 6 | darovskoy
# Processing Record 30 of Set 6 | coahuayana de hidalgo
# Processing Record 31 of Set 6 | bikenibeu village
# Processing Record 32 of Set 6 | tibu
# Processing Record 33 of Set 6 | berdigestyakh
# Processing Record 34 of Set 6 | senahu
# Processing Record 35 of Set 6 | mount pearl
# Processing Record 36 of Set 6 | laizhou
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | rensselaer
# Processing Record 39 of Set 6 | neryungri
# Processing Record 40 of Set 6 | viqueque
# Processing Record 41 of Set 6 | sanga-sanga
# Processing Record 42 of Set 6 | gorgan
# Processing Record 43 of Set 6 | ellsworth
# Processing Record 44 of Set 6 | murghob
# Processing Record 45 of Set 6 | yugorsk
# Processing Record 46 of Set 6 | rio grande
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | ribas do rio pardo
# Processing Record 49 of Set 6 | chibougamau
# Processing Record 0 of Set 7 | xining
# Processing Record 1 of Set 7 | chiang klang
# Processing Record 2 of Set 7 | turbat
# Processing Record 3 of Set 7 | nadym
# Processing Record 4 of Set 7 | faya-largeau
# Processing Record 5 of Set 7 | at taj
# Processing Record 6 of Set 7 | oshakati
# Processing Record 7 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 8 of Set 7 | dryden
# Processing Record 9 of Set 7 | al ghayzah
# Processing Record 10 of Set 7 | tanabe
# Processing Record 11 of Set 7 | ekuvukeni
# Processing Record 12 of Set 7 | carnarvon
# Processing Record 13 of Set 7 | jining
# Processing Record 14 of Set 7 | brezina
# Processing Record 15 of Set 7 | nar'yan-mar
# Processing Record 16 of Set 7 | nola
# Processing Record 17 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 18 of Set 7 | minas
# Processing Record 19 of Set 7 | deba
# Processing Record 20 of Set 7 | kurakhovo
# Processing Record 21 of Set 7 | najran
# Processing Record 22 of Set 7 | international falls
# Processing Record 23 of Set 7 | thurgoona
# Processing Record 24 of Set 7 | mccook
# Processing Record 25 of Set 7 | wailua homesteads
# Processing Record 26 of Set 7 | galliano
# Processing Record 27 of Set 7 | hotan
# Processing Record 28 of Set 7 | labrador city
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | okhotsk
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | mafeteng
# Processing Record 33 of Set 7 | acapulco de juarez
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | fengxian
# Processing Record 36 of Set 7 | howard springs
# Processing Record 37 of Set 7 | ifrane
# Processing Record 38 of Set 7 | malango
# Processing Record 39 of Set 7 | teknaf
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | sungai pelek new village
# Processing Record 42 of Set 7 | lerwick
# Processing Record 43 of Set 7 | kununurra
# Processing Record 44 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 45 of Set 7 | arteaga
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | mount darwin
# Processing Record 48 of Set 7 | san ignacio de velasco
# Processing Record 49 of Set 7 | port blair
# Processing Record 0 of Set 8 | antsiranana
# Processing Record 1 of Set 8 | preobrazheniye
# Processing Record 2 of Set 8 | revda
# Processing Record 3 of Set 8 | tulagi
# Processing Record 4 of Set 8 | ust'-ilimsk
# Processing Record 5 of Set 8 | gadzhiyevo
# Processing Record 6 of Set 8 | nueva concepcion
# Processing Record 7 of Set 8 | dali
# Processing Record 8 of Set 8 | santarem
# Processing Record 9 of Set 8 | matoury
# Processing Record 10 of Set 8 | vilyuchinsk
# Processing Record 11 of Set 8 | mossel bay
# Processing Record 12 of Set 8 | el nido
# Processing Record 13 of Set 8 | mehran
# Processing Record 14 of Set 8 | la'ie
# Processing Record 15 of Set 8 | balezino
# Processing Record 16 of Set 8 | villa regina
# Processing Record 17 of Set 8 | floro
# Processing Record 18 of Set 8 | arraial do cabo
# Processing Record 19 of Set 8 | manokwari
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | nishinoomote
# Processing Record 22 of Set 8 | sabang
# Processing Record 23 of Set 8 | myitkyina
# Processing Record 24 of Set 8 | chiili
# City not found. Skipping...
# Processing Record 25 of Set 8 | zheleznodorozhnyy
# Processing Record 26 of Set 8 | mogocha
# Processing Record 27 of Set 8 | tabou
# Processing Record 28 of Set 8 | ratnagiri
# Processing Record 29 of Set 8 | hammerfest
# Processing Record 30 of Set 8 | orcopampa
# Processing Record 31 of Set 8 | rongelap
# Processing Record 32 of Set 8 | mao
# Processing Record 33 of Set 8 | cururupu
# Processing Record 34 of Set 8 | genhe
# Processing Record 35 of Set 8 | tandlianwala
# Processing Record 36 of Set 8 | lekki
# Processing Record 37 of Set 8 | pahrump
# Processing Record 38 of Set 8 | ritchie
# Processing Record 39 of Set 8 | lib
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | egilsstadir
# Processing Record 42 of Set 8 | katsina-ala
# Processing Record 43 of Set 8 | manicore
# Processing Record 44 of Set 8 | bogen
# Processing Record 45 of Set 8 | darhan
# Processing Record 46 of Set 8 | zemio
# Processing Record 47 of Set 8 | tindouf
# Processing Record 48 of Set 8 | salalah
# Processing Record 49 of Set 8 | port-gentil
# Processing Record 0 of Set 9 | mbanza kongo
# Processing Record 1 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 2 of Set 9 | enewetak
# Processing Record 3 of Set 9 | kapa'a
# Processing Record 4 of Set 9 | gejiu
# Processing Record 5 of Set 9 | pass christian
# Processing Record 6 of Set 9 | fort st. john
# Processing Record 7 of Set 9 | oroqen zizhiqi
# Processing Record 8 of Set 9 | vohipaho
# City not found. Skipping...
# Processing Record 9 of Set 9 | cockburn town
# Processing Record 10 of Set 9 | guerrero negro
# Processing Record 11 of Set 9 | priozersk
# Processing Record 12 of Set 9 | kushiro
# Processing Record 13 of Set 9 | el calafate
# Processing Record 14 of Set 9 | micheweni
# Processing Record 15 of Set 9 | isangel
# Processing Record 16 of Set 9 | fada
# Processing Record 17 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | darwin
# Processing Record 21 of Set 9 | saint-pierre
# Processing Record 22 of Set 9 | kodinsk
# Processing Record 23 of Set 9 | sakaraha
# Processing Record 24 of Set 9 | pocone
# Processing Record 25 of Set 9 | oistins
# Processing Record 26 of Set 9 | korla
# Processing Record 27 of Set 9 | enoch
# Processing Record 28 of Set 9 | beichengqu
# Processing Record 29 of Set 9 | vadso
# Processing Record 30 of Set 9 | as saffaniyah
# Processing Record 31 of Set 9 | santa ana
# Processing Record 32 of Set 9 | rye
# Processing Record 33 of Set 9 | tyul'gan
# Processing Record 34 of Set 9 | tarawa
# Processing Record 35 of Set 9 | molde
# Processing Record 36 of Set 9 | rybnoye
# Processing Record 37 of Set 9 | antonio enes
# Processing Record 38 of Set 9 | ialibu
# Processing Record 39 of Set 9 | ancud
# Processing Record 40 of Set 9 | mermoz boabab
# Processing Record 41 of Set 9 | sao raimundo nonato
# Processing Record 42 of Set 9 | zurrieq
# Processing Record 43 of Set 9 | howrah
# Processing Record 44 of Set 9 | puerto baquerizo moreno
# Processing Record 45 of Set 9 | usinsk
# Processing Record 46 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 47 of Set 9 | kattivakkam
# Processing Record 48 of Set 9 | puerto leguizamo
# Processing Record 49 of Set 9 | tongliao
# Processing Record 0 of Set 10 | yuzhno-kurilsk
# Processing Record 1 of Set 10 | ascencion de guarayos
# Processing Record 2 of Set 10 | anibare
# City not found. Skipping...
# Processing Record 3 of Set 10 | ataq
# Processing Record 4 of Set 10 | stansted mountfitchet
# Processing Record 5 of Set 10 | bhanvad
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | broken hill
# Processing Record 8 of Set 10 | starozhilovo
# Processing Record 9 of Set 10 | kunhegyes
# Processing Record 10 of Set 10 | bereket
# Processing Record 11 of Set 10 | kudahuvadhoo
# Processing Record 12 of Set 10 | east london
# Processing Record 13 of Set 10 | mahdia
# Processing Record 14 of Set 10 | shuangjiang
# Processing Record 15 of Set 10 | island harbour
# Processing Record 16 of Set 10 | ulverstone
# Processing Record 17 of Set 10 | lintong
# Processing Record 18 of Set 10 | buka
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | kiunga
# Processing Record 21 of Set 10 | nowogard
# Processing Record 22 of Set 10 | minab
# Processing Record 23 of Set 10 | dolores
# Processing Record 24 of Set 10 | bandundu
# Processing Record 25 of Set 10 | tortoli
# Processing Record 26 of Set 10 | whitby
# Processing Record 27 of Set 10 | sanctuary point
# Processing Record 28 of Set 10 | balod
# Processing Record 29 of Set 10 | cuajinicuilapa
# Processing Record 30 of Set 10 | bechar
# Processing Record 31 of Set 10 | radaur
# Processing Record 32 of Set 10 | san luis de la loma
# Processing Record 33 of Set 10 | aswan
# Processing Record 34 of Set 10 | kota kinabalu
# Processing Record 35 of Set 10 | estavayer-le-lac
# Processing Record 36 of Set 10 | teguise
# Processing Record 37 of Set 10 | robore
# Processing Record 38 of Set 10 | cill airne
# Processing Record 39 of Set 10 | opuwo
# Processing Record 40 of Set 10 | kill devil hills
# Processing Record 41 of Set 10 | buta
# Processing Record 42 of Set 10 | sechura
# Processing Record 43 of Set 10 | grootfontein
# Processing Record 44 of Set 10 | egersund
# Processing Record 45 of Set 10 | mar del plata
# Processing Record 46 of Set 10 | robertsport
# Processing Record 47 of Set 10 | pont rouge
# Processing Record 48 of Set 10 | jijiga
# Processing Record 49 of Set 10 | vernon
# Processing Record 0 of Set 11 | maceio
# Processing Record 1 of Set 11 | afaahiti
# Processing Record 2 of Set 11 | wynyard
# Processing Record 3 of Set 11 | san pedro
# Processing Record 4 of Set 11 | bodaybo
# Processing Record 5 of Set 11 | bardai
# Processing Record 6 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 11 | kolwezi
# Processing Record 8 of Set 11 | atuncolla
# Processing Record 9 of Set 11 | tidjikja
# Processing Record 10 of Set 11 | saeby
# Processing Record 11 of Set 11 | glace bay
# Processing Record 12 of Set 11 | kone
# Processing Record 13 of Set 11 | nemuro
# Processing Record 14 of Set 11 | bereeda
# Processing Record 15 of Set 11 | port douglas
# Processing Record 16 of Set 11 | freetown
# Processing Record 17 of Set 11 | shubarshi
# Processing Record 18 of Set 11 | randers
# Processing Record 19 of Set 11 | dawesville
# Processing Record 20 of Set 11 | qala i naw
# Processing Record 21 of Set 11 | sisimiut
# Processing Record 22 of Set 11 | saint-philippe
# Processing Record 23 of Set 11 | dauphin
# Processing Record 24 of Set 11 | groningen
# Processing Record 25 of Set 11 | urangan
# Processing Record 26 of Set 11 | poronaysk
# Processing Record 27 of Set 11 | qujing
# Processing Record 28 of Set 11 | hilo
# Processing Record 29 of Set 11 | northam
# Processing Record 30 of Set 11 | nantucket
# Processing Record 31 of Set 11 | kutum
# Processing Record 32 of Set 11 | mumbwa
# Processing Record 33 of Set 11 | diu
# Processing Record 34 of Set 11 | tomatlan
# Processing Record 35 of Set 11 | fort bragg
# Processing Record 36 of Set 11 | harstad
# Processing Record 37 of Set 11 | franceville
# Processing Record 38 of Set 11 | sitia
# Processing Record 39 of Set 11 | tanjung pandan
# Processing Record 40 of Set 11 | sohar
# Processing Record 41 of Set 11 | luchegorsk
# Processing Record 42 of Set 11 | port hedland
# Processing Record 43 of Set 11 | paoua
# Processing Record 44 of Set 11 | obidos
# Processing Record 45 of Set 11 | ashburton
# Processing Record 46 of Set 11 | kohtla-jarve
# Processing Record 47 of Set 11 | namibe
# Processing Record 48 of Set 11 | loch garman
# Processing Record 49 of Set 11 | bodo
# Processing Record 0 of Set 12 | deschutes river woods
# Processing Record 1 of Set 12 | nenjiang
# Processing Record 2 of Set 12 | kolonia town
# Processing Record 3 of Set 12 | brokopondo
# Processing Record 4 of Set 12 | sinabang
# Processing Record 5 of Set 12 | sarangani
# Processing Record 6 of Set 12 | shchuchyn
# Processing Record 7 of Set 12 | galesong
# Processing Record 8 of Set 12 | maunabo
# Processing Record 9 of Set 12 | manistee
# Processing Record 10 of Set 12 | bad frankenhausen
# Processing Record 11 of Set 12 | conde
# Processing Record 12 of Set 12 | verkhnevilyuysk
# Processing Record 13 of Set 12 | kasongo-lunda
# Processing Record 14 of Set 12 | tlacotepec
# Processing Record 15 of Set 12 | zhezqazghan
# Processing Record 16 of Set 12 | balykshi
# Processing Record 17 of Set 12 | oranjemund
# Processing Record 18 of Set 12 | nkhotakota
# Processing Record 19 of Set 12 | kuanda
# Processing Record 20 of Set 12 | kidal
# Processing Record 21 of Set 12 | ulladulla
# Processing Record 22 of Set 12 | nikolayevsk-on-amure
# Processing Record 23 of Set 12 | zabol
# Processing Record 24 of Set 12 | paracatu
# Processing Record 25 of Set 12 | sao felipe
# Processing Record 26 of Set 12 | cavan
# Processing Record 27 of Set 12 | fortuna foothills
# Processing Record 28 of Set 12 | springfield
# Processing Record 29 of Set 12 | nouadhibou
# Processing Record 30 of Set 12 | sarandi del yi
# Processing Record 31 of Set 12 | tabuk
# Processing Record 32 of Set 12 | felege neway
# Processing Record 33 of Set 12 | gebeit
# Processing Record 34 of Set 12 | sulejow
# Processing Record 35 of Set 12 | chinhoyi
# Processing Record 36 of Set 12 | miguel calmon
# Processing Record 37 of Set 12 | quatre cocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()

current_date = datetime.now()
city_datetime = datetime.utcfromtimestamp(city_date)
formatted_date = city_datetime.strftime('%Y-%m-%d')
#print(formatted_date)

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   igarka  67.4667   86.5833    -13.00        89         100
# 1                    qamdo  31.1667   97.2333     -4.68        52           0
# 2        port saint john's -31.6229   29.5448     20.76        89         100
# 3                    creel  27.7500 -107.6333      5.12        42           1
# 4                   rikaze  29.2500   88.8833     -2.03        25           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.68      RU  1733447052
# 1              0.84      CN  1733447053
# 2              2.91      ZA  1733447054
# 3              2.59      MX  1733447055
# 4              0.50      CN  1733447056

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#function for scatter plots
def scatter_plot(x,y):
    plt.scatter(city_data_df[x], city_data_df[y], c="lightblue", marker="h", edgecolor="black")
    plt.tight_layout()
    plt.grid()

# %%
# Build scatter plot for latitude vs. temperature
scatter_plot("Lat", "Max Temp")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
scatter_plot("Lat", "Humidity")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
scatter_plot("Lat", "Cloudiness")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Cloudiness ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
scatter_plot("Lat","Wind Speed")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Cloudiness ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_values, y_values):
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    print(f"The r^2 Value is: {r_value**2:}")

    return slope, intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        igarka  67.4667   86.5833    -13.00        89         100
# 1         qamdo  31.1667   97.2333     -4.68        52           0
# 3         creel  27.7500 -107.6333      5.12        42           1
# 4        rikaze  29.2500   88.8833     -2.03        25           0
# 5        anadyr  64.7500  177.4833    -22.72        77          63
#
#          Wind Speed Country        Date
# City_ID
# 0              6.68      RU  1733447052
# 1              0.84      CN  1733447053
# 3              2.59      MX  1733447055
# 4              0.50      CN  1733447056
# 5              4.00      RU  1733446911

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port saint john's -31.6229   29.5448     20.76        89         100
# 6            port mathurin -19.6833   63.4167     24.49        76          56
# 10                waitangi -43.9535 -176.5597     13.79        85          42
# 11              codrington -38.2667  141.9667     20.22        66         100
# 12                  alotau -10.3069  150.4462     31.22        65         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.91      ZA  1733447054
# 6              9.55      MU  1733447058
# 10             4.92      NZ  1733446819
# 11             1.55      AU  1733447064
# 12             2.23      PG  1733447065

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
slope, intercept = linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], color="lightblue", edgecolors="black",marker='h')
plt.plot(northern_hemi_df["Lat"], slope * northern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Max Temp ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.729127419982578

# %%
# Linear regression on Southern Hemisphere
slope, intercept = linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], color="lightblue", edgecolors="black",marker='h')
plt.plot(southern_hemi_df["Lat"], slope * southern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Max Temp ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.3202458834598396

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The result from the data showed that there is a strong negative correlation between latitude and max temperature for northern hemisphere. Whereas, there is a moderate positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept = linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], color="lightblue", edgecolors="black",marker='h')
plt.plot(northern_hemi_df["Lat"], slope * northern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Humidity ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.09368785870809415

# %%
# Southern Hemisphere
slope, intercept = linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], color="lightblue", edgecolors="black",marker='h')
plt.plot(southern_hemi_df["Lat"], slope * southern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Humidity ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-50,5),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.07241485023014424

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is little to no relationship between latitude and humidity based on the data available.
# The linear equation for each hemisphere shows a very slightly positive correlation, which implies that proximity to the equator has no bearing on humdity.
# The scatter points exhibit that the data is too spread for there to be any reliable correlation between latitude and humidity.
# Both the Northern and Souther Hemispheres exhibit a weak correlations between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept = linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], color="lightblue", edgecolors="black",marker='h')
plt.plot(northern_hemi_df["Lat"], slope * northern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Cloudiness ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(50,50),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.05102136701168604

# %%
# Southern Hemisphere
slope, intercept = linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], color="lightblue", edgecolors="black",marker='h')
plt.plot(southern_hemi_df["Lat"], slope * southern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Cloudiness ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.012130528675180052

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The result from the data showed that there is a very week, almost none negative correlation between Cloudiness and Latitude in the Southern Hemisphere cities.Whereas there is a a weak positive correlation between latitude and cloudiness for Northern Hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept = linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], color="lightblue", edgecolors="black",marker='h')
plt.plot(northern_hemi_df["Lat"], slope * northern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Wind Speed ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(30,14),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.04141097453118992

# %%
# Southern Hemisphere
slope, intercept = linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], color="lightblue", edgecolors="black",marker='h')
plt.plot(southern_hemi_df["Lat"], slope * southern_hemi_df["Lat"] + intercept, color="red")
plt.title(f"Latitude vs. Wind Speed ({current_date.year}-{current_date.month}-{current_date.day})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.grid(True)
plt.show()
# Out:
# The r^2 Value is: 0.03967070466300262

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The Northern Hemisphere plot is a linear regression model between Wind Speed and latitude.
# The result from the data showed that there is a very week, positive correlation between Wind Speed and Latitude in the Northern Hemisphere cities.
# And there is a very week, negative correlation between Wind Speed and Latitude in the Southern Hemisphere cities.
